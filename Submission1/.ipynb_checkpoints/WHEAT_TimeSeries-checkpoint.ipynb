# %% [markdown]
# # Wheat TIime Series

# %%
print('Nama                 : Aldi Akbar Alimi')
print('Username dicoding    : alldinosaur')
print('Email                : aldiakbar373@gmail.com')
print('Domisili             : Kab. Cirebon')
print('TTL                  : Brebes, 25 Juni 2001')
print('Pendidikan Terakhir  : SMA Negeri 1 Brebes')
print('Pendidikan Sekarang  : STT Terpadu Nurul Fikri')
# Out:
# Nama                 : Aldi Akbar Alimi
# Username dicoding    : alldinosaur
# Email                : aldiakbar373@gmail.com
# Domisili             : Kab. Cirebon
# TTL                  : Brebes, 25 Juni 2001
# Pendidikan Terakhir  : SMA Negeri 1 Brebes
# Pendidikan Sekarang  : STT Terpadu Nurul Fikri

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Dropout,SimpleRNN,LSTM
from keras.models import Sequential

# %%
df_visualize = pd.read_csv('datasets/commodity_futures.csv', index_col='Date', parse_dates=['Date'])
df = pd.read_csv('datasets/commodity_futures.csv')
df.head()
# Out:
#          Date  NATURAL GAS   GOLD  WTI CRUDE  BRENT CRUDE  SOYBEANS    CORN  \
# 0  2000-01-03          NaN    NaN        NaN          NaN    456.50  200.75
# 1  2000-01-04        2.176  283.7      25.55        24.39    464.25  203.00
# 2  2000-01-05        2.168  282.1      24.91        23.73    469.25  203.00
# 3  2000-01-06        2.196  282.4      24.78        23.62    468.00  203.75
# 4  2000-01-07        2.173  282.9      24.22        23.09    471.50  207.00
#
#    COPPER  SILVER  LOW SULPHUR GAS OIL  ...     ZINC  ULS DIESEL  NICKEL  \
# 0     NaN     NaN                  NaN  ...  1237.50         NaN  8446.0
# 1  0.8480   5.375               213.50  ...  1215.00       67.78  8314.0
# 2  0.8565   5.210               213.00  ...  1209.25       66.55  8307.0
# 3  0.8530   5.167               211.25  ...  1212.00       66.28  8252.0
# 4  0.8540   5.195               205.25  ...  1209.25       64.75  8174.0
#
#     WHEAT  SUGAR  GASOLINE  COFFEE  LEAN HOGS  HRW WHEAT  COTTON
# ...

# %%
df = df[["Date", "WHEAT"]]
df
# Out:
#             Date   WHEAT
# 0     2000-01-03  247.50
# 1     2000-01-04  247.25
# 2     2000-01-05  249.75
# 3     2000-01-06  248.50
# 4     2000-01-07  251.75
# ...          ...     ...
# 5853  2022-09-05  775.50
# 5854  2022-09-06  800.00
# 5855  2022-09-07  826.50
# 5856  2022-09-08  810.50
# 5857  2022-09-09  810.00
#
# [5858 rows x 2 columns]

# %%
df_visualize = df_visualize[['WHEAT']]
df_visualize
# Out:
#              WHEAT
# Date
# 2000-01-03  247.50
# 2000-01-04  247.25
# 2000-01-05  249.75
# 2000-01-06  248.50
# 2000-01-07  251.75
# ...            ...
# 2022-09-05  775.50
# 2022-09-06  800.00
# 2022-09-07  826.50
# 2022-09-08  810.50
# 2022-09-09  810.00
#
# [5858 rows x 1 columns]

# %%
#checking missing data
df.isna().sum()
# Out:
# Date     0
# WHEAT    0
# dtype: int64

# %%
df_visualize.plot(figsize=(20,5),legend=True)
plt.title('WHEAT Price Over Time (Daily Frecuency) ~ Before Normalization',
          fontsize=20);
plt.ylabel('Price (quoted in EUR/bushel)')
plt.show()

# %%
def normalize_data(df):
    scaler = sklearn.preprocessing.MinMaxScaler()
    df['WHEAT']=scaler.fit_transform(df['WHEAT'].values.reshape(-1,1))
    df_visualize['WHEAT']=scaler.fit_transform(df_visualize['WHEAT'].values.reshape(-1,1))
    return df

df_norm = normalize_data(df)
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_9544/2205476025.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_visualize['WHEAT']=scaler.fit_transform(df_visualize['WHEAT'].values.reshape(-1,1))

# %%
df_visualize.plot(figsize=(20,5),legend=True)
plt.title('WHEAT Price Over Time (Daily Frecuency) ~ Before Normalization',
          fontsize=20);
plt.ylabel('Price (quoted in EUR/bushel)')
plt.show()
